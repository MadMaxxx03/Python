# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('1.8_homework.csv')
df.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
subset_1 = df.iloc[:10, [0,2]]
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
df.iloc[:, [1,3]].drop([0,4], axis=0)
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %%
subset_1 = df.query('V1 > 0 and V3 == "A"')
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
subset_2 = df.query('V2 != 10 or V4 >= 1')
subset_2
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
df['V5'] = df['V1'] + df['V4']
df
# Out:
#      V1    V2 V3   V4   V5
# 0     2  13.0  B  1.0  3.0
# 1    -1   7.0  B  1.0  0.0
# 2     0  11.0  A  0.0  0.0
# 3     2  11.0  A  2.0  4.0
# 4     0  10.0  B -1.0 -1.0
# ..   ..   ... ..  ...  ...
# 495   1   8.0  A -1.0  0.0
# 496   3   8.0  A  1.0  4.0
# 497  -1  11.0  B  2.0  1.0
# 498   1  11.0  A  2.0  3.0
# 499   0   8.0  B  1.0  1.0
#
# [500 rows x 5 columns]

# %%
df['V6'] = np.log(df['V2'])
df
# Out:
#      V1   V2 V3   V4   V5   V6
# 0     2  1.0  B  1.0  3.0  0.0
# 1    -1  1.0  B  1.0  0.0  0.0
# 2     0  1.0  A  0.0  0.0  0.0
# 3     2  1.0  A  2.0  4.0  0.0
# 4     0  1.0  B -1.0 -1.0  0.0
# ..   ..  ... ..  ...  ...  ...
# 495   1  1.0  A -1.0  0.0  0.0
# 496   3  1.0  A  1.0  4.0  0.0
# 497  -1  1.0  B  2.0  1.0  0.0
# 498   1  1.0  A  2.0  3.0  0.0
# 499   0  1.0  B  1.0  1.0  0.0
#
# [500 rows x 6 columns]

# %%
df = df.rename(columns={'V1':'session_value', 'V2':'group', 'V3':'time', 'V4':'n_users'})
df
# Out:
#      session_value  group time  n_users   V5   V6
# 0                2    1.0    B      1.0  3.0  0.0
# 1               -1    1.0    B      1.0  0.0  0.0
# 2                0    1.0    A      0.0  0.0  0.0
# 3                2    1.0    A      2.0  4.0  0.0
# 4                0    1.0    B     -1.0 -1.0  0.0
# ..             ...    ...  ...      ...  ...  ...
# 495              1    1.0    A     -1.0  0.0  0.0
# 496              3    1.0    A      1.0  4.0  0.0
# 497             -1    1.0    B      2.0  1.0  0.0
# 498              1    1.0    A      2.0  3.0  0.0
# 499              0    1.0    B      1.0  1.0  0.0
#
# [500 rows x 6 columns]

# %%
df['session_value'].fillna(0)
df
# Out:
#      session_value  group time  n_users   V5   V6
# 0                2    1.0    B      1.0  3.0  0.0
# 1               -1    1.0    B      1.0  0.0  0.0
# 2                0    1.0    A      0.0  0.0  0.0
# 3                2    1.0    A      2.0  4.0  0.0
# 4                0    1.0    B     -1.0 -1.0  0.0
# ..             ...    ...  ...      ...  ...  ...
# 495              1    1.0    A     -1.0  0.0  0.0
# 496              3    1.0    A      1.0  4.0  0.0
# 497             -1    1.0    B      2.0  1.0  0.0
# 498              1    1.0    A      2.0  3.0  0.0
# 499              0    1.0    B      1.0  1.0  0.0
#
# [500 rows x 6 columns]

# %%
df.loc[df['n_users'] < 0, 'n_users'] = df.query('n_users >= 0').n_users.median()
df
# Out:
#      session_value  group time  n_users   V5   V6
# 0                2    1.0    B      1.0  3.0  0.0
# 1               -1    1.0    B      1.0  0.0  0.0
# 2                0    1.0    A      0.0  0.0  0.0
# 3                2    1.0    A      2.0  4.0  0.0
# 4                0    1.0    B      1.0 -1.0  0.0
# ..             ...    ...  ...      ...  ...  ...
# 495              1    1.0    A      1.0  0.0  0.0
# 496              3    1.0    A      1.0  4.0  0.0
# 497             -1    1.0    B      2.0  1.0  0.0
# 498              1    1.0    A      2.0  3.0  0.0
# 499              0    1.0    B      1.0  1.0  0.0
#
# [500 rows x 6 columns]

# %%
df
# Out:
#      session_value  group time  n_users   V5   V6
# 0                2    1.0    B      1.0  3.0  0.0
# 1               -1    1.0    B      1.0  0.0  0.0
# 2                0    1.0    A      0.0  0.0  0.0
# 3                2    1.0    A      2.0  4.0  0.0
# 4                0    1.0    B      1.0 -1.0  0.0
# ..             ...    ...  ...      ...  ...  ...
# 495              1    1.0    A      1.0  0.0  0.0
# 496              3    1.0    A      1.0  4.0  0.0
# 497             -1    1.0    B      2.0  1.0  0.0
# 498              1    1.0    A      2.0  3.0  0.0
# 499              0    1.0    B      1.0  1.0  0.0
#
# [500 rows x 6 columns]

# %%
df.groupby('group').n_users.count()
# Out:
# group
# 1.0    500
# Name: n_users, dtype: int64
