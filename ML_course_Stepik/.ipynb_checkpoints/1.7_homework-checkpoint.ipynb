# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('1.7_homework.csv')

# %%
data.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
data['income'].plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=data)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=data.index, y=data.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
data.income.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(data.index, data.income)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10276\1034557743.py in <module>
# ----> 1 plt.plot(data.index, data.income)
#
# NameError: name 'plt' is not defined

# %%
data.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("1.7_homework.txt", sep=" ")
df.head()
# Out:
#              x            y
# 0   513.472820   286.455519
# 1   797.273308  1097.158292
# 2   189.618085   802.043017
# 3  1011.021127   501.542310
# 4   387.080420  1198.123447

# %%
sns.scatterplot(x=df.x, y=df.y)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('1.7_2_homework.csv', index_col=0)

# %%
df.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(df, cmap='YlOrBr');
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df = pd.read_csv('1.6_homework.csv', index_col=0)
df.head()
# Out:
#   attack_type  id  legs  localized_name                          name  \
# 0       Melee   1     2       Anti-Mage        npc_dota_hero_antimage
# 1       Melee   2     2             Axe             npc_dota_hero_axe
# 2      Ranged   3     4            Bane            npc_dota_hero_bane
# 3       Melee   4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4      Ranged   5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
#
#   primary_attr                                              roles
# 0          agi                       ['Carry', 'Escape', 'Nuker']
# 1          str    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          int        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3          agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          int        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
sns.lineplot(df, hue='roles')
# Out:
# C:\Users\baben_bakg1j1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12972\3321727630.py in <module>
# ----> 1 sns.lineplot(df, hue='roles')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
lenths = [len(r.split(',')) for r in df.roles]
df['lenths'] = lenths

# %%
df = df.rename(columns={"lenths": "role_count"})

# %%
sns.histplot(df.role_count)
# Out:
# <AxesSubplot:xlabel='role_count', ylabel='Count'>

# %%
df = pd.read_csv('1.7_3_homework.csv', index_col=0)

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
for column in df:
    sns.kdeplot(df[str(column)])

# %%
sns.kdeplot(data=df)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(df,  vars=df.columns[:-1], diag_kind='kde')

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.violinplot(data=df['petal length'])
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True, cmap= 'viridis')
# Out:
# <AxesSubplot:>
